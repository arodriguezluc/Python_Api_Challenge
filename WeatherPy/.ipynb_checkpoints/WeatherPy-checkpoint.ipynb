# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import scipy.stats as st
from scipy.stats import linregress

# Import API key
import api_keys
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print (citipy)
# Out:
# <module 'citipy.citipy' from 'C:\\Users\\arodr\\anaconda3\\lib\\site-packages\\citipy\\citipy.py'>

# %% [markdown]
# ## Generate Cities List

# %%
#Print today's date
today = f"{datetime.datetime.now():%m/%d/%y}"
print (today)
# Out:
# 05/29/21

# %%
# List for holding lat_Lngs and cities
lat_lngs = []
cities = []

# Creates a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat & lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # For each unique city name, then add it to the cities list
    if city not in cities:
        cities.append(city)

# Print city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# create lists that hold reponse information
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

# %%
# Loop through the list of cities and execute a request for data on each city item

print('Beginning Data Retrieval')     
print('_________________________')
i=0 

for city in cities:
    #print(f"query_url is : {query_url}")
    response = requests.get(query_url + city).json()
    #print(f"response is : {response}")
    cod = response['cod']
    if cod == 200: 
        i = i + 1
        City.append(response['name'])
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        print(f'Processing Record {i} of Set 1 | {city}')
    else:
        print(f'City not found. Skipping...')
    
print(f'______________________________')
print(f'Data Retrieval Complete     ')
print(f'______________________________')
# Out:
# Beginning Data Retrieval
# _________________________
# City not found. Skipping...
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | lazaro cardenas
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | asau
# Processing Record 11 of Set 1 | lorengau
# Processing Record 12 of Set 1 | los llanos de aridane
# Processing Record 13 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 14 of Set 1 | waitati
# Processing Record 15 of Set 1 | margate
# City not found. Skipping...
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | hami
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | kudat
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | vila
# Processing Record 25 of Set 1 | beloha
# Processing Record 26 of Set 1 | sao geraldo do araguaia
# Processing Record 27 of Set 1 | puerto colombia
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | zhangjiakou
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | saint-andre-les-vergers
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | andujar
# Processing Record 36 of Set 1 | jiexiu
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | arequipa
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | pemberton
# City not found. Skipping...
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | te anau
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | amuntai
# Processing Record 49 of Set 1 | haines junction
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 51 of Set 1 | hammerfest
# Processing Record 52 of Set 1 | constitucion
# Processing Record 53 of Set 1 | faanui
# Processing Record 54 of Set 1 | ponta do sol
# Processing Record 55 of Set 1 | ust-nera
# Processing Record 56 of Set 1 | praia
# Processing Record 57 of Set 1 | vila franca do campo
# Processing Record 58 of Set 1 | lom sak
# City not found. Skipping...
# Processing Record 59 of Set 1 | fortuna
# Processing Record 60 of Set 1 | lufilufi
# Processing Record 61 of Set 1 | krasnoselkup
# Processing Record 62 of Set 1 | muravlenko
# Processing Record 63 of Set 1 | puerto ayora
# Processing Record 64 of Set 1 | brasileia
# Processing Record 65 of Set 1 | tashla
# Processing Record 66 of Set 1 | sisimiut
# Processing Record 67 of Set 1 | piranhas
# Processing Record 68 of Set 1 | lagoa
# Processing Record 354 of Set 1 | pevek
# Processing Record 355 of Set 1 | arys
# Processing Record 356 of Set 1 | pervomayskoye
# Processing Record 357 of Set 1 | willowmore
# Processing Record 358 of Set 1 | sambava
# Processing Record 359 of Set 1 | arrifes
# Processing Record 360 of Set 1 | gubkinskiy
# Processing Record 361 of Set 1 | port hardy
# Processing Record 362 of Set 1 | masuguru
# Processing Record 363 of Set 1 | cayenne
# Processing Record 364 of Set 1 | salme
# Processing Record 365 of Set 1 | kholodnyy
# Processing Record 366 of Set 1 | nuuk
# Processing Record 367 of Set 1 | korla
# Processing Record 368 of Set 1 | taoudenni
# Processing Record 369 of Set 1 | umm lajj
# Processing Record 370 of Set 1 | iskateley
# Processing Record 371 of Set 1 | kieta
# Processing Record 372 of Set 1 | coquimbo
# Processing Record 373 of Set 1 | brae
# City not found. Skipping...
# Processing Record 374 of Set 1 | baykit
# Processing Record 375 of Set 1 | lawton
# Processing Record 376 of Set 1 | biltine
# Processing Record 377 of Set 1 | ellensburg
# Processing Record 378 of Set 1 | abu samrah
# Processing Record 379 of Set 1 | kununurra
# Processing Record 380 of Set 1 | halifax
# Processing Record 381 of Set 1 | kyren
# Processing Record 382 of Set 1 | saint-felicien
# Processing Record 383 of Set 1 | vesyegonsk
# Processing Record 384 of Set 1 | balkhash
# Processing Record 385 of Set 1 | batagay-alyta
# Processing Record 386 of Set 1 | kavieng
# Processing Record 387 of Set 1 | inirida
# Processing Record 388 of Set 1 | fort nelson
# Processing Record 389 of Set 1 | sovetskiy
# Processing Record 390 of Set 1 | altamira
# Processing Record 391 of Set 1 | buala
# Processing Record 392 of Set 1 | lompoc
# Processing Record 393 of Set 1 | waipawa
# Processing Record 394 of Set 1 | port moresby
# Processing Record 395 of Set 1 | pangkalanbuun
# Processing Record 396 of Set 1 | kachiry
# Processing Record 397 of Set 1 | kapoeta
# Processing Record 398 of Set 1 | sheridan
# Processing Record 399 of Set 1 | khingansk
# Processing Record 400 of Set 1 | roquetas de mar
# Processing Record 401 of Set 1 | dezful
# Processing Record 402 of Set 1 | burnie
# Processing Record 403 of Set 1 | nerchinskiy zavod
# Processing Record 404 of Set 1 | moron
# City not found. Skipping...
# Processing Record 405 of Set 1 | morondava
# Processing Record 406 of Set 1 | manggar
# Processing Record 407 of Set 1 | phan thiet
# Processing Record 408 of Set 1 | rolla
# Processing Record 409 of Set 1 | alice springs
# Processing Record 410 of Set 1 | severo-kurilsk
# Processing Record 411 of Set 1 | padang
# Processing Record 412 of Set 1 | kovur
# Processing Record 413 of Set 1 | zirandaro
# Processing Record 414 of Set 1 | pimenta bueno
# Processing Record 415 of Set 1 | vila velha
# Processing Record 416 of Set 1 | straumen
# Processing Record 417 of Set 1 | paramonga
# Processing Record 418 of Set 1 | amahai
# Processing Record 419 of Set 1 | ryotsu
# Processing Record 420 of Set 1 | kalengwa
# Processing Record 421 of Set 1 | warragul
# Processing Record 422 of Set 1 | manama
# Processing Record 423 of Set 1 | port elizabeth
# Processing Record 424 of Set 1 | catacamas
# Processing Record 495 of Set 1 | buluang
# Processing Record 496 of Set 1 | deli tua
# Processing Record 497 of Set 1 | teahupoo
# Processing Record 498 of Set 1 | broken hill
# Processing Record 499 of Set 1 | ninghai
# Processing Record 500 of Set 1 | shakhtinsk
# Processing Record 501 of Set 1 | sao miguel
# Processing Record 502 of Set 1 | chiquilistlan
# Processing Record 503 of Set 1 | opuwo
# Processing Record 504 of Set 1 | shimoda
# Processing Record 505 of Set 1 | rayagada
# Processing Record 506 of Set 1 | ahipara
# Processing Record 507 of Set 1 | chapais
# Processing Record 508 of Set 1 | roald
# Processing Record 509 of Set 1 | kaeo
# Processing Record 510 of Set 1 | mulege
# Processing Record 511 of Set 1 | durazno
# Processing Record 512 of Set 1 | woodmere
# Processing Record 513 of Set 1 | labytnangi
# Processing Record 514 of Set 1 | barcelos
# Processing Record 515 of Set 1 | sakaiminato
# Processing Record 516 of Set 1 | praia da vitoria
# Processing Record 517 of Set 1 | lesnoye
# Processing Record 518 of Set 1 | kisiwani
# Processing Record 519 of Set 1 | deputatskiy
# City not found. Skipping...
# Processing Record 520 of Set 1 | abha
# Processing Record 521 of Set 1 | atbasar
# Processing Record 522 of Set 1 | calvinia
# Processing Record 523 of Set 1 | faya
# Processing Record 524 of Set 1 | tricase
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 525 of Set 1 | yaring
# Processing Record 526 of Set 1 | blagoyevo
# Processing Record 527 of Set 1 | shenjiamen
# Processing Record 528 of Set 1 | kutum
# City not found. Skipping...
# Processing Record 529 of Set 1 | vestmanna
# City not found. Skipping...
# Processing Record 530 of Set 1 | lauro muller
# Processing Record 531 of Set 1 | bubaque
# Processing Record 532 of Set 1 | konya
# Processing Record 533 of Set 1 | masumbwe
# City not found. Skipping...
# Processing Record 534 of Set 1 | cocula
# Processing Record 535 of Set 1 | novita
# Processing Record 536 of Set 1 | micheweni
# Processing Record 537 of Set 1 | belyy yar
# Processing Record 538 of Set 1 | cumbitara
# Processing Record 539 of Set 1 | zharkent
# Processing Record 540 of Set 1 | oussouye
# Processing Record 541 of Set 1 | luderitz
# Processing Record 542 of Set 1 | kotido
# City not found. Skipping...
# Processing Record 543 of Set 1 | tazovskiy
# Processing Record 544 of Set 1 | newbury
# Processing Record 545 of Set 1 | lata
# Processing Record 546 of Set 1 | terra santa
# Processing Record 547 of Set 1 | garissa
# Processing Record 548 of Set 1 | jinchang
# Processing Record 549 of Set 1 | avera
# Processing Record 550 of Set 1 | shalinskoye
# Processing Record 551 of Set 1 | aksarka
# Processing Record 552 of Set 1 | cam ranh
# Processing Record 553 of Set 1 | nishihara
# City not found. Skipping...
# Processing Record 554 of Set 1 | adrar
# Processing Record 555 of Set 1 | manzanillo
# Processing Record 556 of Set 1 | benguela
# Processing Record 557 of Set 1 | puerto leguizamo
# Processing Record 558 of Set 1 | ocos
# Processing Record 559 of Set 1 | rumford
# Processing Record 560 of Set 1 | rawson
# Processing Record 561 of Set 1 | puerto carreno
# Processing Record 562 of Set 1 | tobol
# Processing Record 563 of Set 1 | tarma
# Processing Record 564 of Set 1 | liepaja
# Processing Record 565 of Set 1 | lasa
# Processing Record 566 of Set 1 | sechura
# Processing Record 567 of Set 1 | tonantins
# Processing Record 568 of Set 1 | zalantun
# City not found. Skipping...
# Processing Record 569 of Set 1 | majholi
# Processing Record 570 of Set 1 | seymchan
# Processing Record 571 of Set 1 | mitsamiouli
# Processing Record 572 of Set 1 | beringovskiy
# Processing Record 573 of Set 1 | ridgecrest
# Processing Record 574 of Set 1 | takoradi
# Processing Record 575 of Set 1 | bage
# Processing Record 576 of Set 1 | gualaquiza
# Processing Record 577 of Set 1 | iseyin
# Processing Record 578 of Set 1 | antanifotsy
# Processing Record 579 of Set 1 | medicine hat
# ______________________________
# Data Retrieval Complete
# ______________________________

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = pd.DataFrame({
    "City": City,
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp": Max_Temp,
    "Wind Speed": Wind_Speed})

weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv('WeatherPy_data.csv')

# print the lengh of each list 
print(f'City          {len(City)}')
print(f'Cloudiness    {len(Cloudiness)}')
print(f'Country    {len(Country)}')
print(f'Date    {len(Date)}')
print(f'Humidity    {len(Humidity)}')
print(f'Lat    {len(Lat)}')
print(f'Lng    {len(Lng)}')
print(f'Max Temp    {len(Max_Temp)}')
print(f'Wind Speed    {len(Wind_Speed)}')
# Out:
# City          559
# Cloudiness    559
# Country    559
# Date    559
# Humidity    559
# Lat    559
# Lng    559
# Max Temp    559
# Wind Speed    559

# %%
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0   Clyde River          40      CA  1622313129        69  70.4692  -68.5914
# 1        Dingle          96      PH  1622313122        91  10.9995  122.6711
# 2  Saint George           1      US  1622313081        13  37.1041 -113.5841
# 3       Qaanaaq          49      GL  1622313093        95  77.4840  -69.3632
# 4        Hobart          90      AU  1622313101        78 -42.8794  147.3294
#
#    Max Temp  Wind Speed
# 0     32.23        3.44
# 1     77.83        2.17
# 2     89.64        1.99
# 3     31.69        5.77
# 4     45.27        3.00

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#plot Latitude vs Max_Temperature
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.scatter(Lat, Max_Temp, marker="o", alpha=.75, color = "red",edgecolor = "black")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#plot Latitude vs Humidity
plt.title(f"City Latitude vs. Humidity ({today})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


plt.scatter(Lat, Humidity, marker="o", alpha=.75, color = "orange",edgecolor = "black")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#plot Latitude vs Cloudiness
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


plt.scatter(Lat, Cloudiness, marker="o", alpha=.75, color = "blue",edgecolor = "black")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#plot Latitude vs Wind Speed
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")


plt.scatter(Lat, Wind_Speed, alpha=.75, color = "green",edgecolor = "black")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Define the function that creates a linear Regression and catter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")
plt.savefig("../Instructions/Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.83

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")
plt.savefig("../Instructions/Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.81

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

plt.savefig("../Instructions/Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.12

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Instructions/Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.0

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Instructions/Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.01

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Instructions/Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.02

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Instructions/Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Instructions/Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.25
